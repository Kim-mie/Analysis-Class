# %% [markdown]
# # Hello World (largest)
# ## Hello WORLD
# ### Hello World
# #### Hello World
# ##### hELLO World
# ###### HelloWorld (smallest text)
#
# *text in italic*
# **text in bold**

# %%
print("Habari Dunia")
# Out:
# Habari Dunia

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
def greet(name):
    return f"Hello, {name}!"
print(greet("Solomon"))
# Out:
# Hello, Solomon!

# %%
def task():
    print("This is a task.")    
task()
# Out:
# This is a task.
